# %%
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
ipl=pd.read_csv(r'C:\Users\Tushar\Desktop\matches.csv',encoding='latin1')

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.shape
# Out:
# (636, 18)

# %%
ipl.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
ipl.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
ipl['player_of_match'].value_counts()[:10]
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# MS Dhoni          13
# G Gambhir         13
# AM Rahane         12
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
y1=list(ipl['player_of_match'].value_counts()[:10].keys())

# %%
y2=list(ipl['player_of_match'].value_counts()[:10])

# %%
plt.figure(figsize=(18,5))
plt.bar(y1,y2,color='olive')
# Out:
# <BarContainer object of 10 artists>

# %%
ipl['result'].value_counts()
# Out:
# normal       626
# tie            7
# no result      3
# Name: result, dtype: int64

# %%
ipl['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
#team won by choosing batting first
l1=ipl[ipl['win_by_runs']!=0]

# %%
l1
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 13    14    2017        Kolkata  2017-04-15        Kolkata Knight Riders
# 14    15    2017          Delhi  2017-04-15             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 625  626    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 633  634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
l1.tail()
# Out:
#       id  season           city        date                        team1  \
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 625  626    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 633  634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2              toss_winner toss_decision  \
# 624      Rising Pune Supergiants  Rising Pune Supergiants         field
# 625              Kings XI Punjab          Kings XI Punjab         field
# 630          Sunrisers Hyderabad      Sunrisers Hyderabad         field
# 633        Kolkata Knight Riders    Kolkata Knight Riders         field
# 635  Royal Challengers Bangalore      Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.hist(l1['win_by_runs'],color='orange')
plt.title('Distribution of Runs')
plt.xlabel('Runs')
plt.ylabel('Matches')
# Out:
# Text(0, 0.5, 'Matches')

# %%
l1['winner'].value_counts()
# Out:
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Sunrisers Hyderabad            23
# Rajasthan Royals               23
# Delhi Daredevils               21
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
p1=list(l1['winner'].value_counts()[:5].keys())

# %%
p2=list(l1['winner'].value_counts()[:5])

# %%
plt.figure(figsize=(18,5))
plt.bar(p1,p2)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,7))
plt.pie(p2,labels=p1,autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d091b872e0>,
# ...
#  [Text(0.7712210281984136, 0.7843584165829941, 'Mumbai Indians'),
#   Text(-0.7843584165829941, 0.7712210281984136, 'Chennai Super Kings'),
#   Text(-0.9432028500286289, -0.5660109395567119, 'Kings XI Punjab'),
#   Text(0.03715157212014607, -1.099372439480362, 'Kolkata Knight Riders'),
#   Text(0.9617812858204875, -0.533832144260244, 'Royal Challengers Bangalore')],
#  [Text(0.42066601538095283, 0.42783186359072406, '25.3%'),
#   Text(-0.42783186359072406, 0.42066601538095283, '24.7%'),
#   Text(-0.5144742818337975, -0.3087332397582065, '17.2%'),
#   Text(0.020264493883716032, -0.5996576942620154, '16.7%'),
#   Text(0.5246079740839023, -0.29118116959649665, '16.1%')])

# %%
batting_second=ipl[ipl['win_by_wickets']!=0]

# %%
batting_second
# Out:
#       id  season           city        date                   team1  \
# 1      2    2017           Pune  2017-04-06          Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...            ...         ...                     ...
# 628  629    2016  Visakhapatnam  2016-05-21         Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016         Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016          Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
batting_second.shape
# Out:
# (339, 18)

# %%
batting_second.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  339.000000   339.000000  339.000000        339.0      339.000000
# mean   319.896755  2012.533923    0.020649          0.0        6.327434
# std    186.695124     2.818136    0.142416          0.0        1.796327
# min      2.000000  2008.000000    0.000000          0.0        1.000000
# 25%    158.000000  2010.000000    0.000000          0.0        5.000000
# 50%    323.000000  2012.000000    0.000000          0.0        6.000000
# 75%    484.000000  2015.000000    0.000000          0.0        8.000000
# max    635.000000  2017.000000    1.000000          0.0       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
plt.hist(batting_second['win_by_wickets'],color='black',bins=20)
plt.title('Distribution Of Wickets')
plt.xlabel('Wickets')
plt.ylabel('Matches')
# Out:
# Text(0, 0.5, 'Matches')

# %%
batting_second['winner'].value_counts()
# Out:
# Kolkata Knight Riders          46
# Mumbai Indians                 44
# Royal Challengers Bangalore    42
# Delhi Daredevils               41
# Rajasthan Royals               38
# Kings XI Punjab                36
# Chennai Super Kings            33
# Sunrisers Hyderabad            18
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
m1=list(batting_second['winner'].value_counts()[:10].keys())

# %%
m2=list(batting_second['winner'].value_counts()[:10])

# %%
plt.figure(figsize=(25,5))
plt.bar(m1,m2,color='olive')
plt.xlabel('Teams')
plt.title('Teams Win By Wickets')
# Out:
# Text(0.5, 1.0, 'Teams Win By Wickets')

# %%
plt.pie(m2,labels=m1,autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d08ea20970>,
# ...
#  [Text(0.9903974889794074, 0.4786573031128689, 'Kolkata Knight Riders'),
#   Text(0.2612365656385012, 1.0685295769296241, 'Mumbai Indians'),
#   Text(-0.6228250913583726, 0.9066911853406511, 'Royal Challengers Bangalore'),
#   Text(-1.0865412588574312, 0.17154618270456742, 'Delhi Daredevils'),
#   Text(-0.8974505397335767, -0.6360680220950524, 'Rajasthan Royals'),
#   Text(-0.25076665612957144, -1.0710350527287114, 'Kings XI Punjab'),
#   Text(0.47380513166815585, -0.9927279069336783, 'Chennai Super Kings'),
#   Text(0.8911825635628354, -0.6448206249815316, 'Sunrisers Hyderabad'),
#   Text(1.0396608462614536, -0.3593122941828159, 'Gujarat Lions'),
#   Text(1.0936317768736352, -0.11819279424827667, 'Deccan Chargers')],
#  [Text(0.5402168121705858, 0.26108580169792844, '14.3%'),
#   Text(0.14249267216645517, 0.5828343146888858, '13.7%'),
#   Text(-0.33972277710456683, 0.4945588283676278, '13.1%'),
# ...

# %%
ipl['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
np.sum(ipl['winner']==ipl['toss_winner'])/636*100
# Out:
# 51.100628930817614

# %%
ipl2=pd.read_csv(r'C:\Users\Tushar\Downloads\deliveries.csv',encoding='latin1')
ipl2
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
match_1=ipl2[ipl2['match_id']==1]

# %%
match_1
# Out:
#      match_id  inning                 batting_team  \
# 0           1       1          Sunrisers Hyderabad
# 1           1       1          Sunrisers Hyderabad
# 2           1       1          Sunrisers Hyderabad
# 3           1       1          Sunrisers Hyderabad
# 4           1       1          Sunrisers Hyderabad
# ..        ...     ...                          ...
# 243         1       2  Royal Challengers Bangalore
# 244         1       2  Royal Challengers Bangalore
# 245         1       2  Royal Challengers Bangalore
# 246         1       2  Royal Challengers Bangalore
# 247         1       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball      batsman  non_striker  \
# 0    Royal Challengers Bangalore     1     1    DA Warner     S Dhawan
# 1    Royal Challengers Bangalore     1     2    DA Warner     S Dhawan
# 2    Royal Challengers Bangalore     1     3    DA Warner     S Dhawan
# ...

# %%
248/6
# Out:
# 41.333333333333336

# %%
srh=match_1[match_1['inning']==1]

# %%
srh
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 0           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# ..        ...     ...                  ...                          ...   ...
# 120         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 121         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 122         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 123         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 124         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
#
# ...

# %%
srh['batsman_runs'].value_counts()
# Out:
# 1    57
# 0    32
# 4    17
# 6     9
# 2     9
# 3     1
# Name: batsman_runs, dtype: int64

# %%
srh['dismissal_kind'].value_counts()
# Out:
# caught    3
# bowled    1
# Name: dismissal_kind, dtype: int64

# %%
rcb=match_1[match_1['inning']==2]

# %%
rcb
# Out:
#      match_id  inning                 batting_team         bowling_team  over  \
# 125         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 126         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 127         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 128         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 129         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# ..        ...     ...                          ...                  ...   ...
# 243         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    19
# 244         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
# 245         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
# 246         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
# 247         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
#
# ...

# %%
rcb['batsman_runs'].value_counts()
# Out:
# 0    49
# 1    44
# 4    15
# 6     8
# 2     7
# Name: batsman_runs, dtype: int64

# %%
rcb['dismissal_kind'].value_counts()
# Out:
# caught     6
# bowled     2
# run out    2
# Name: dismissal_kind, dtype: int64

# %%
match_2=ipl2[ipl2['match_id']==2]

# %%
match_2.describe()
# Out:
#        match_id      inning        over        ball  is_super_over  \
# count     247.0  247.000000  247.000000  247.000000          247.0
# mean        2.0    1.493927   10.497976    3.603239            0.0
# std         0.0    0.500978    5.793095    1.791032            0.0
# min         2.0    1.000000    1.000000    1.000000            0.0
# 25%         2.0    1.000000    5.500000    2.000000            0.0
# 50%         2.0    1.000000   11.000000    4.000000            0.0
# 75%         2.0    2.000000   15.000000    5.000000            0.0
# max         2.0    2.000000   20.000000    7.000000            0.0
#
#         wide_runs    bye_runs  legbye_runs  noball_runs  penalty_runs  \
# count  247.000000  247.000000   247.000000        247.0         247.0
# mean     0.036437    0.004049     0.008097          0.0           0.0
# std      0.208284    0.063628     0.089801          0.0           0.0
# min      0.000000    0.000000     0.000000          0.0           0.0
# ...

# %%
srh2=match_2[match_2['inning']==1]

# %%
srh2
# Out:
#      match_id  inning    batting_team            bowling_team  over  ball  \
# 248         2       1  Mumbai Indians  Rising Pune Supergiant     1     1
# 249         2       1  Mumbai Indians  Rising Pune Supergiant     1     2
# 250         2       1  Mumbai Indians  Rising Pune Supergiant     1     3
# 251         2       1  Mumbai Indians  Rising Pune Supergiant     1     4
# 252         2       1  Mumbai Indians  Rising Pune Supergiant     1     5
# ..        ...     ...             ...                     ...   ...   ...
# 368         2       1  Mumbai Indians  Rising Pune Supergiant    20     3
# 369         2       1  Mumbai Indians  Rising Pune Supergiant    20     4
# 370         2       1  Mumbai Indians  Rising Pune Supergiant    20     5
# 371         2       1  Mumbai Indians  Rising Pune Supergiant    20     6
# 372         2       1  Mumbai Indians  Rising Pune Supergiant    20     7
#
#         batsman     non_striker    bowler  is_super_over  ...  bye_runs  \
# ...

# %%
srh2['batsman_runs'].value_counts()
# Out:
# 1    49
# 0    48
# 4    12
# 6    11
# 2     4
# 5     1
# Name: batsman_runs, dtype: int64

# %%
srh2['dismissal_kind'].value_counts()
# Out:
# caught               3
# bowled               2
# lbw                  1
# caught and bowled    1
# run out              1
# Name: dismissal_kind, dtype: int64

# %%
np.sum(srh2['batsman_runs'])
# Out:
# 176

# %%
np.sum(srh2['dismissal_kind'].value_counts())
# Out:
# 8

# %%
srh22=match_2[match_2['inning']==2]

# %%
(srh22['batsman_runs'].value_counts())
# Out:
# 1    55
# 0    33
# 4    18
# 2    10
# 6     6
# Name: batsman_runs, dtype: int64

# %%
srh2['dismissal_kind'].value_counts()
# Out:
# caught               3
# bowled               2
# lbw                  1
# caught and bowled    1
# run out              1
# Name: dismissal_kind, dtype: int64

# %%
plt.bar(list(srh2['dismissal_kind'].value_counts().keys()[:5]),list(srh2['dismissal_kind'].value_counts()[:5]))
# Out:
# <BarContainer object of 5 artists>

# %%
m2=list(srh22['batsman_runs'].value_counts()[:5])

# %%
m3=list(srh22['batsman_runs'].value_counts().keys()[:5])

# %%
plt.bar(m3,m2)
plt.xlabel('Types Of Runs')
plt.ylabel('Total Runs')
plt.title('Batsman Runs')
# Out:
# Text(0.5, 1.0, 'Batsman Runs')

# %%
np.sum(srh22['dismissal_kind'].value_counts())
# Out:
# 3

# %%
plt.bar(list(srh22['batsman_runs'].value_counts().keys()[:5]),list(srh22['batsman_runs'].value_counts()[:5]))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist(m2)
# Out:
# (array([2., 0., 1., 0., 0., 1., 0., 0., 0., 1.]),
#  array([ 6. , 10.9, 15.8, 20.7, 25.6, 30.5, 35.4, 40.3, 45.2, 50.1, 55. ]),
#  <BarContainer object of 10 artists>)

# %%
ipl['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
ipl['toss_winner']
# Out:
# 0      Royal Challengers Bangalore
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633          Kolkata Knight Riders
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: toss_winner, Length: 636, dtype: object

# %%
list(ipl['winner'].value_counts()[:10].keys())
# Out:
# ['Mumbai Indians',
#  'Chennai Super Kings',
#  'Kolkata Knight Riders',
#  'Royal Challengers Bangalore',
#  'Kings XI Punjab',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Sunrisers Hyderabad',
#  'Deccan Chargers',
#  'Gujarat Lions']

# %%
ipl['player_of_match'].value_counts()[:9]
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# MS Dhoni          13
# G Gambhir         13
# AM Rahane         12
# Name: player_of_match, dtype: int64

# %%
ipl['player_of_match'].value_counts()[9:]
# Out:
# MEK Hussey     12
# V Sehwag       11
# DR Smith       11
# V Kohli        11
# SR Watson      10
#                ..
# AD Mathews      1
# LR Shukla       1
# R Bhatia        1
# A Singh         1
# BCJ Cutting     1
# Name: player_of_match, Length: 192, dtype: int64

# %%
ipl['umpire1'].value_counts()
# Out:
# HDPK Dharmasena          73
# Asad Rauf                51
# AK Chaudhary             43
# Aleem Dar                38
# BF Bowden                37
# S Ravi                   36
# BR Doctrove              34
# M Erasmus                32
# RE Koertzen              20
# S Asnani                 19
# JD Cloete                16
# CB Gaffaney              14
# AY Dandekar              13
# BG Jerling               13
# NJ Llong                 12
# KN Ananthapadmanabhan    11
# A Nand Kishore           11
# VA Kulkarni              11
# SS Hazare                11
# Nitin Menon              11
# RK Illingworth           11
# K Hariharan              10
# MR Benson                10
# S Das                    10
# DJ Harper                 9
# RM Deshpande              7
# GAV Baxter                7
# IL Howell                 7
# BNJ Oxenford              7
# C Shamshuddin             6
# SJ Davis                  6
# SD Fry                    5
# SK Tarapore               5
# ...

# %%
ipl['umpire2'].value_counts()
# Out:
# SJA Taufel         54
# C Shamshuddin      50
# S Ravi             49
# RJ Tucker          38
# CK Nandan          36
# RB Tiffin          30
# VA Kulkarni        28
# SK Tarapore        26
# BNJ Oxenford       25
# AM Saheba          23
# M Erasmus          22
# RE Koertzen        21
# DJ Harper          18
# AK Chaudhary       15
# HDPK Dharmasena    14
# NJ Llong           13
# K Srinath          13
# SL Shastri         13
# K Hariharan        11
# S Asnani           11
# CB Gaffaney        10
# VK Sharma           9
# PR Reiffel          8
# RK Illingworth      8
# BR Doctrove         8
# Nitin Menon         8
# IL Howell           7
# I Shivram           6
# SS Hazare           6
# AL Hill             6
# GA Pratapkumar      6
# PG Pathak           6
# TH Wijewardene      5
# A Nand Kishore      5
# S Das               5
# BG Jerling          4
# AV Jayaprakash      4
# K Srinivasan        3
# A Deshmukh          3
# SD Ranade           2
# MR Benson           2
# ...
